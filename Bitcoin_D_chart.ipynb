# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitv13/Python_sumit/blob/main/Bitcoin_D_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.graph_objects as go

df =pd.read_csv('/content/drive/MyDrive/Python/Bitstamp_BTCUSD_d.csv');

df=df.iloc[::-1]

df['date']=pd.to_datetime(df['date'])
df['20ma']= df['close'].rolling(window =20).mean()
df['50ma']= df['close'].rolling(window =50).mean()
fig =go.Figure(data =[go.Candlestick(x=df['date']
,open=df['open']
,high=df['high']
,low =df['low']
,close=df['close'])])

fig.add_trace(go.Scatter(x=df["date"],y=df["20ma"],line=dict(color ="#1f2dcc"),
name="20 days ma"
))

fig.add_trace(go.Scatter(x=df["date"],y=df["50ma"],line=dict(color ="#211e1e"),
name="500 days ma"
))
fig.update_layout(xaxis_rangeslider_visible=False )
fig.update_layout(yaxis_title ="Bit price USD", xaxis_title ="date")
fig.update_yaxes(type="log")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ef926c24-b973-4c8f-af47-ee764c1c85ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef926c24-b973-4c8f-af47-ee764c1c85ba")) {
#                     Plotly.newPlot(
#                         'ef926c24-b973-4c8f-af47-ee764c1c85ba',
# ...

# %% [markdown]
# # New Section
